# %%
import pandas as pd
df = pd.read_csv('ufc_fight_stats.csv')  
df.head(1)
# Out:
#                                   EVENT  \
# 0  UFC Fight Night: Adesanya vs. Imavov
#
#                                      BOUT    ROUND          FIGHTER   KD  \
# 0  Israel Adesanya vs. Nassourdine Imavov  Round 1  Israel Adesanya  0.0
#
#    SIG.STR. SIG.STR. % TOTAL STR.      TD TD %  SUB.ATT  REV.  CTRL     HEAD  \
# 0  20 of 44        45%   26 of 50  0 of 1   0%      0.0   0.0  0:00  8 of 27
#
#      BODY      LEG  DISTANCE  CLINCH  GROUND
# 0  3 of 5  9 of 12  20 of 44  0 of 0  0 of 0

# %%
# CONVERT object TO FLOAT64
# SIG.STR. %
df['SIG.STR. %'] = df['SIG.STR. %'].str.replace('%', '', regex=False) # (regex=False) literal character
df['SIG.STR. %'] = pd.to_numeric(df['SIG.STR. %'], errors='coerce')
df['SIG.STR. %'] = df['SIG.STR. %'] / 100

# SIG.STR. %
df['TD %'] = df['TD %'].str.replace('%', '', regex=False)
df['TD %'] = pd.to_numeric(df['TD %'], errors='coerce')
df['TD %'] = df['TD %'] / 100

# SPLIT COLUMNS BY 'OF' DELIMETER

# SIG.STR column
df[['SIG.STR.SUC', 'SIG.STR.TOT']] = df['SIG.STR.'].str.split(' of ', expand=True)

# TD column
df[['TD.SUC', 'TD.TOT']] = df['TD'].str.split(' of ', expand=True)

# HEAD column split
df[['HEAD.SUC', 'HEAD.TOT']] = df['HEAD'].str.split(' of ', expand=True) # Split column
df['HEAD.SUC'] = pd.to_numeric(df['HEAD.SUC']) # Convert to float64
df['HEAD.TOT'] = pd.to_numeric(df['HEAD.TOT']) # Convert to float64
df['HEAD %'] = df['HEAD.SUC']/df['HEAD.TOT'] # Create new column

# BODY column
df[['BODY.SUC', 'BODY.TOT']] = df['BODY'].str.split(' of ', expand=True) # Split column
df['BODY.SUC'] = pd.to_numeric(df['BODY.SUC']) # Convert to float64
df['BODY.TOT'] = pd.to_numeric(df['BODY.TOT']) # Convert to float64
df['BODY %'] = df['BODY.SUC']/df['BODY.TOT'] # Create new column

# LEG column
df[['LEG.SUC', 'LEG.TOT']] = df['LEG'].str.split(' of ', expand=True) # Split column
df['LEG.SUC'] = pd.to_numeric(df['LEG.SUC']) # Convert to float64
df['LEG.TOT'] = pd.to_numeric(df['LEG.TOT']) # Convert to float64
df['LEG %'] = df['LEG.SUC']/df['LEG.TOT'] # Create new column

# DISTANCE column
df[['DISTANCE.SUC', 'DISTANCE.TOT']] = df['DISTANCE'].str.split(' of ', expand=True) # Split column
df['DISTANCE.SUC'] = pd.to_numeric(df['DISTANCE.SUC']) # Convert to float64
df['DISTANCE.TOT'] = pd.to_numeric(df['DISTANCE.TOT']) # Convert to float64
df['DISTANCE %'] = df['DISTANCE.SUC']/df['DISTANCE.TOT'] # Create new column

# CLINCH column
df[['CLINCH.SUC', 'CLINCH.TOT']] = df['CLINCH'].str.split(' of ', expand=True) # Split column
df['CLINCH.SUC'] = pd.to_numeric(df['CLINCH.SUC']) # Convert to float64
df['CLINCH.TOT'] = pd.to_numeric(df['CLINCH.TOT']) # Convert to float64
df['CLINCH %'] = df['CLINCH.SUC']/df['CLINCH.TOT'] # Create new column

# GROUND column
df[['GROUND.SUC', 'GROUND.TOT']] = df['GROUND'].str.split(' of ', expand=True) # Split column
df['GROUND.SUC'] = pd.to_numeric(df['GROUND.SUC']) # Convert to float64
df['GROUND.TOT'] = pd.to_numeric(df['GROUND.TOT']) # Convert to float64
df['GROUND %'] = df['GROUND.SUC']/df['GROUND.TOT'] # Create new column

# Remove (drop) columns
df = df.drop(columns=['TOTAL STR.', 'SIG.STR.', 'TD', 'TD.SUC', 'HEAD', 'HEAD.SUC', 'BODY', 'BODY.SUC', 'LEG', 'LEG.SUC', 'DISTANCE', 'CLINCH', 'CLINCH.SUC', 'GROUND', 'GROUND.SUC'])

# Print df
print(df.columns)

# Save to .csv
df.to_csv('ufc_fight_stats_clean.csv', index=True)
# Out:
# Index(['EVENT', 'BOUT', 'ROUND', 'FIGHTER', 'KD', 'SIG.STR. %', 'TD %',
#        'SUB.ATT', 'REV.', 'CTRL', 'SIG.STR.SUC', 'SIG.STR.TOT', 'TD.TOT',
#        'HEAD.TOT', 'HEAD %', 'BODY.TOT', 'BODY %', 'LEG.TOT', 'LEG %',
#        'DISTANCE.SUC', 'DISTANCE.TOT', 'DISTANCE %', 'CLINCH.TOT', 'CLINCH %',
#        'GROUND.TOT', 'GROUND %'],
#       dtype='object')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
