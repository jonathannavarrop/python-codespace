# %%
# Import necessary libraries
import pandas as pd

# Load the fight results data
df = pd.read_csv('ufc_fight_results.csv')
df2 = pd.read_csv('ufc_fighter_tott_clean.csv')

# Display the first few rows of the dataframe
df.head(5)
# Out:
#                                      EVENT  \
# 0  UFC 322: Della Maddalena vs. Makhachev
# 1  UFC 322: Della Maddalena vs. Makhachev
# 2  UFC 322: Della Maddalena vs. Makhachev
# 3  UFC 322: Della Maddalena vs. Makhachev
# 4  UFC 322: Della Maddalena vs. Makhachev
#
#                                          BOUT OUTCOME  \
# 0  Jack Della Maddalena  vs. Islam Makhachev      L/W
# 1      Valentina Shevchenko  vs. Zhang Weili      W/L
# 2            Sean Brady  vs. Michael Morales      L/W
# 3            Leon Edwards  vs. Carlos Prates      L/W
# 4     Beneil Dariush  vs. Benoit Saint Denis      L/W
#
#                         WEIGHTCLASS                 METHOD  ROUND  TIME  \
# 0       UFC Welterweight Title Bout  Decision - Unanimous       5  5:00
# 1  UFC Women's Flyweight Title Bout  Decision - Unanimous       5  5:00
# 2                 Welterweight Bout                KO/TKO       1  3:27
# 3                 Welterweight Bout                KO/TKO       2  1:28
# 4                  Lightweight Bout                KO/TKO       1  0:16
#
#          TIME FORMAT         REFEREE  \
# 0  5 Rnd (5-5-5-5-5)       Herb Dean
# 1  5 Rnd (5-5-5-5-5)    Marc Goddard
# 2      3 Rnd (5-5-5)     Blake Grice
# 3      3 Rnd (5-5-5)  Keith Peterson
# 4      3 Rnd (5-5-5)       Herb Dean
#
#                                              DETAILS  \
# 0  Derek Cleary 45 - 50.Sal D'amato 45 - 50.Ron M...
# 1  Chris Bolinski 45 - 50.Eric Colon 45 - 50.Chri...
# 2                       Punches to Head At Distance
# 3                         Punch to Head At Distance
# 4                         Punch to Head At Distance
#
#                                                  URL
# 0  http://ufcstats.com/fight-details/856f6ee04937...
# 1  http://ufcstats.com/fight-details/7606f6b6c19f...
# 2  http://ufcstats.com/fight-details/477af74ea3cb...
# 3  http://ufcstats.com/fight-details/3c6088485376...
# 4  http://ufcstats.com/fight-details/9b5f190cd3f5...

# %%
# Separate BOUT columns into FIGHTER1 and FIGHTER2
df[['FIGHTER1', 'FIGHTER2']] = df['BOUT'].str.split(' vs. ', expand=True)

# Trim whitespace from fighter names
df['FIGHTER1'] = df['FIGHTER1'].str.strip()
df['FIGHTER2'] = df['FIGHTER2'].str.strip()

# Function to assign winner and loser
def assign_winner_loser(row):
    if row['OUTCOME'] == 'W/L': # Winner is FIGHTER1
        return pd.Series([row['FIGHTER1'], row['FIGHTER2']])
    elif row['OUTCOME'] == 'L/W': # Winner is FIGHTER2
        return pd.Series([row['FIGHTER2'], row['FIGHTER1']])
    else: # Draw or No Contest
        return pd.Series([None, None])

# Apply the function to assign WINNER and LOSER
df[['WINNER', 'LOSER']] = df.apply(assign_winner_loser, axis=1)

# Assign METHOD Decision/KO/Sub
def assign_method(row):
    if 'Decision' in row['METHOD']:
        return 'Decision'
    elif 'KO/TKO' in row['METHOD'] or 'TKO' in row['METHOD']:
        return 'KO/TKO'
    elif 'Submission' in row['METHOD']:
        return 'Submission'
    elif 'Overturned' in row['METHOD']:
        return 'NC'
    else:
        return row['METHOD']
    
# Apply the function to assign METHOD type
df['METHOD'] = df.apply(assign_method, axis=1)

# Merge AGE from df2 into df for both fighters
df = df.merge(df2[['FIGHTER', 'AGE']], left_on='WINNER', right_on='FIGHTER', how='left').drop(columns= 'FIGHTER').rename(columns={'AGE':'AGE1'})
df = df.merge(df2[['FIGHTER','AGE']], left_on='LOSER', right_on='FIGHTER', how='left').drop(columns= 'FIGHTER').rename(columns={'AGE':'AGE2'})

# Calculate absolute age difference
df['AGE.DIFF.WINNER'] = df['AGE1'] - df['AGE2']

# Drop unnecessary columns
df = df.drop(columns=['OUTCOME', 'TIME FORMAT', 'REFEREE', 'URL', 'FIGHTER1', 'FIGHTER2', 'AGE1', 'AGE2'])

# Save the cleaned dataframe to a new CSV file
df.to_csv('ufc_fight_results_clean.csv', index=False)

# Display the first few rows of the updated dataframe
df.head(5)
# Out:
#                                      EVENT  \
# 0  UFC 322: Della Maddalena vs. Makhachev
# 1  UFC 322: Della Maddalena vs. Makhachev
# 2  UFC 322: Della Maddalena vs. Makhachev
# 3  UFC 322: Della Maddalena vs. Makhachev
# 4  UFC 322: Della Maddalena vs. Makhachev
#
#                                          BOUT  \
# 0  Jack Della Maddalena  vs. Islam Makhachev
# 1      Valentina Shevchenko  vs. Zhang Weili
# 2            Sean Brady  vs. Michael Morales
# 3            Leon Edwards  vs. Carlos Prates
# 4     Beneil Dariush  vs. Benoit Saint Denis
#
#                         WEIGHTCLASS    METHOD  ROUND  TIME  \
# 0       UFC Welterweight Title Bout  Decision      5  5:00
# 1  UFC Women's Flyweight Title Bout  Decision      5  5:00
# 2                 Welterweight Bout    KO/TKO      1  3:27
# 3                 Welterweight Bout    KO/TKO      2  1:28
# 4                  Lightweight Bout    KO/TKO      1  0:16
#
#                                              DETAILS                WINNER  \
# 0  Derek Cleary 45 - 50.Sal D'amato 45 - 50.Ron M...       Islam Makhachev
# 1  Chris Bolinski 45 - 50.Eric Colon 45 - 50.Chri...  Valentina Shevchenko
# 2                       Punches to Head At Distance        Michael Morales
# 3                         Punch to Head At Distance          Carlos Prates
# 4                         Punch to Head At Distance     Benoit Saint Denis
#
#                   LOSER  AGE.DIFF.WINNER
# 0  Jack Della Maddalena         4.876712
# 1           Zhang Weili         1.435616
# 2            Sean Brady        -6.586301
# 3          Leon Edwards        -1.980822
# 4        Beneil Dariush        -6.621918
